# %%
import pandas as pd

file_name = ["soviet","공대생변승주","오늘의하늘","오킹","해그린달"]
for file in file_name:
    df = pd.read_excel(file+"6개월이내.xlsx")
    df = df.drop(["Unnamed: 0"],axis = "columns")
    
    썸네일 = df["thumbnail"]
    제목 = df["title"]
    분야 = df["title_type"]
    조회수 = df["view_count"]
    좋아요수 = df["likes_count"]
    싫어요수 = df["dislikes_count"]
    한달업로드수 = df["term"]
    영상길이 = df["video_length"]
# Out:
# 0      6:04
# 1      5:29
# 2      6:38
# 3      6:47
# 4      5:04
# 5      5:47
# 6      6:23
# 7      7:15
# 8      6:06
# 9      4:49
# 10     4:21
# 11     5:26
# 12     5:03
# 13     5:09
# 14     4:20
# 15     6:25
# 16     5:42
# 17     5:26
# 18     6:52
# 19     6:08
# 20     5:11
# 21     6:18
# 22     5:48
# 23     6:31
# 24     5:46
# 25    10:03
# 26     5:05
# 27     0:12
# 28     5:25
# 29     6:01
# 30     4:22
# 31     1:56
# 32     2:54
# 33     1:06
# 34     6:37
# 35     5:44
# 36     5:27
# 37     5:51
# 38     5:11
# Name: video_length, dtype: object
# 0     11:23
# 1      7:22
# 2     11:06
# 3      6:44
# 4      5:54
#       ...
# 85    10:05
# 86     6:34
# 87     4:30
# 88    10:13
# 89    10:08
# Name: video_length, Length: 90, dtype: object
# 0     17:04
# 1     16:48
# 2     16:30
# 3     18:23
# 4     15:21
#       ...
# 81    17:43
# 82    10:02
# 83    14:44
# 84    15:45
# 85    16:11
# Name: video_length, Length: 86, dtype: object
# 0     10:26
# 1     13:57
# 2     10:01
# 3     10:09
# 4     10:20
#       ...
# 81    11:52
# 82    13:49
# 83    14:56
# 84    14:19
# 85     7:02
# Name: video_length, Length: 86, dtype: object
# 0     12:46
# 1     13:38
# 2     14:16
# 3     14:04
# 4     10:11
# 5      7:19
# 6     14:08
# 7     14:06
# 8      6:53
# 9      7:24
# 10    13:36
# 11     7:59
# 12    13:33
# 13    13:40
# 14    11:32
# 15    14:50
# 16     7:48
# 17    15:53
# 18    15:19
# 19    21:40
# 20    14:19
# 21     7:57
# 22    16:21
# 23    13:34
# 24    10:14
# 25    14:39
# 26    17:40
# 27    16:58
# 28    14:37
# 29    16:02
# 30    15:29
# 31    13:30
# 32    14:02
# 33    15:09
# 34    16:05
# 35    13:21
# 36    14:03
# Name: video_length, dtype: object
