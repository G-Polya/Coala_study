# %%
import pandas as pd
from datetime import datetime

df = pd.read_excel("6개월이내 총합.xlsx")

df = df.drop(["Unnamed: 8"],axis="columns")

# %%
df
# Out:
#      category  dislikes_count  likes_count  \
# 0          동물             772        25000
# 1      엔터테인먼트             340        22000
# 2      엔터테인먼트             136        12000
# 3      엔터테인먼트             309        36000
# 4      엔터테인먼트            2000        48000
# 5      엔터테인먼트             791        34000
# 6      인물/블로그             166        17000
# 7      여행/이벤트             156        18000
# 8      여행/이벤트             368        19000
# 9      엔터테인먼트             250        15000
# 10     엔터테인먼트             442        44000
# 11     인물/블로그             385        28000
# 12        코미디             314        26000
# 13       과학기술             448        30000
# 14   비영리/사회운동             235        15000
# 15     엔터테인먼트             324        19000
# 16     여행/이벤트             471        24000
# 17        코미디             161        12000
# 18     인물/블로그            1900        49000
# 19    노하우/스타일             803        30000
# 20    노하우/스타일             495        28000
# ...

# %%
애완 = df[df["분류"]=="애완"].sort_values("view_count",ascending=False).head(10)

# %%
일상 = df[df["분류"]=="일상"].sort_values("view_count",ascending=False).head(10)

# %%
장난 = df[df["분류"]=="장난"].sort_values("view_count",ascending=False).head(10)

# %%
여행 = df[df["분류"]=="여행"].sort_values("view_count",ascending=False).head(10)

# %%
리뷰 = df[df["분류"]=="리뷰"].sort_values("view_count",ascending=False).head(10)

# %%
type(애완)
# Out:
# pandas.core.frame.DataFrame

# %%
temp = pd.DataFrame()
temp =pd.concat([temp,애완,일상,여행,리뷰,장난],ignore_index= True)

# %%
len(temp)
# Out:
# 41

# %%
temp = temp.drop(["category"],axis="columns")

# %%
temp
# Out:
#     dislikes_count  likes_count  \
# 0              772        25000
# 1             2000        48000
# 2             1900        49000
# 3              509        19000
# 4              803        30000
# 5              599        28000
# 6              791        34000
# 7              501        13000
# 8              495        28000
# 9              448        30000
# 10             369        12000
# 11             442        44000
# 12             471        24000
# 13             343        13000
# 14             324        19000
# 15             368        19000
# 16             340        22000
# 17             225        16000
# 18             161        12000
# 19             132        13000
# 20             113         6100
# 21             317        21000
# 22             337        19000
# 23             250        17000
# 24             283        17000
# 25               0            0
# 26             141         7500
# 27             101         7300
# ...

# %%
temp.to_excel("최종직전의데이터(일상).xlsx")

# %%
final_data = pd.DataFrame({
    "분야": "일상",
    "제목타입":temp[]
})
