# %%
import pandas as pd

file_names = ["soviet","공대생변승주","냔지","미트",
              "박병창","오늘의하늘","오킹",
             "윽박이","이승인",
             "해그린달"]
all_df = pd.DataFrame()


for file in file_names:
    df = pd.read_excel(file+"_최종규격.xlsx")
    all_df = all_df.append(df,ignore_index = False)


all_df.to_excel("all_data.xlsx")

# %%
all_df
# Out:
#         구독자 수      구독자수  분야  싫어요 수  썸네일   영상길이  제목      조회수   좋아요 수  한달업로드 수
# 0         NaN  790000.0  일상    772  1.0   6:04   1   891271   25000        4
# 1         NaN  790000.0  일상    340  2.5   5:29   0   740904   22000        4
# 2         NaN  790000.0  일상    136  2.0   6:38   1   482429   12000        4
# 3         NaN  790000.0  일상    309  2.0   6:47   1   990325   36000        4
# 4         NaN  790000.0  일상   2000  2.0   5:04   1  2564107   48000        4
# 5         NaN  790000.0  일상    791  2.0   5:47   1  1718884   34000        4
# 6         NaN  790000.0  일상    166  2.5   6:23   0   761152   17000        4
# 7         NaN  790000.0  일상    156  2.5   7:15   0   668095   18000        4
# 8         NaN  790000.0  일상    368  2.5   6:06   0   866957   19000        4
# 9         NaN  790000.0  일상    250  2.5   4:49   1   658346   15000        4
# 10        NaN  790000.0  일상    442  2.5   4:21   0  1796245   44000        4
# ...
