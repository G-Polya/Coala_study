# %%
import pandas as pd

file_name = ["soviet","공대생변승주","오늘의하늘","오킹","해그린달"]
for file in file_name:
    df = pd.read_excel(file+"6개월이내.xlsx")
    df = df.drop(["Unnamed: 0"],axis = "columns")
    
    썸네일 = df["thumbnail_type"]
    제목 = df["title"]
    분야 = df["title_type"]
    조회수 = df["view_count"]
    좋아요수 = df["likes_count"]
    싫어요수 = df["dislikes_count"]
    한달업로드수 = df["term"]
    영상길이 = df["video_length"]
    
    df2 = pd.DataFrame({
        "썸네일" : 썸네일,
        "제목" : 제목,
        "분야" : 분야,
        "조회수" : 조회수
        "좋아요수" : 좋아요수
        
    })
# Out:
# 0     1.0
# 1     2.5
# 2     2.0
# 3     2.0
# 4     2.0
# 5     2.0
# 6     2.5
# 7     2.5
# 8     2.5
# 9     2.5
# 10    2.5
# 11    2.0
# 12    2.5
# 13    2.5
# 14    2.5
# 15    2.5
# 16    2.5
# 17    2.5
# 18    2.5
# 19    2.5
# 20    2.5
# 21    2.5
# 22    2.5
# 23    2.5
# 24    2.5
# 25    2.5
# 26    2.5
# 27    2.5
# 28    2.5
# 29    2.5
# 30    2.5
# 31    2.5
# 32    2.5
# 33    2.5
# 34    2.5
# 35    2.5
# 36    2.5
# 37    2.5
# 38    2.5
# Name: thumbnail_type, dtype: float64
# 0     3.5
# 1     3.5
# 2     2.5
# 3     2.5
# 4     2.0
#      ...
# 85    3.0
# 86    1.5
# 87    1.0
# 88    1.5
# 89    2.5
# Name: thumbnail_type, Length: 90, dtype: float64
# 0     2.0
# 1     3.5
# 2     3.5
# 3     3.5
# 4     2.0
#      ...
# 81    3.5
# 82    2.0
# 83    3.5
# 84    3.5
# 85    1.5
# Name: thumbnail_type, Length: 86, dtype: float64
# 0     2.5
# 1     2.5
# 2     2.5
# 3     2.5
# 4     2.5
#      ...
# 81    2.5
# 82    1.0
# 83    2.5
# 84    3.5
# ...
